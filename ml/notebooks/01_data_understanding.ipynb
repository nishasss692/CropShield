# %% [markdown]
# # 01 - Data Understanding & Exploratory Data Analysis
#
# This notebook covers initial data exploration, inspection, and summary statistics.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
